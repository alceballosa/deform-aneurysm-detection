# %%
import torch 

path_weights = "/home/azureuser/workspace/medical/weights/output_cnn_adamw2/checkpoint0100.pth"

weights = torch.load(path_weights, weights_only = False)

# %%
weights.keys()
# Out:
# dict_keys(['student', 'teacher', 'optimizer', 'epoch', 'args', 'dino_loss', 'fp16_scaler'])

# %%
for module in weights["teacher"].keys():
    print(weights["teacher"][module].shape)
# Out:
# torch.Size([32, 1, 3, 3, 3])
# torch.Size([32])
# torch.Size([32])
# torch.Size([32])
# torch.Size([32])
# torch.Size([])
# torch.Size([96, 32, 3, 3, 3])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([])
# torch.Size([96, 96, 3, 3, 3])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([])
# torch.Size([96, 96, 3, 3, 3])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([])
# torch.Size([96, 96, 3, 3, 3])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([])
# torch.Size([96, 96, 3, 3, 3])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([96])
# torch.Size([])
# torch.Size([128, 96, 2, 2, 2])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([])
# torch.Size([128, 128, 3, 3, 3])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# torch.Size([128])
# ...
