# %%
path_vessel = "/projects/vig/Datasets/aneurysm/cta_datasets/internal_train/crop_0.4_vessel"

path_compressed = "/projects/vig/Datasets/aneurysm/cta_datasets/internal_train/crop_0.4_compressed"

# %%
import SimpleITK as sitk 
from pathlib import Path 
import tqdm 

# for each scan, load both the vessel and compressed, then check how many vessel voxels (1 or 2) are == -512
#

vessel_files = sorted(Path(path_vessel).glob("*.nii.gz"))
compressed_files = sorted(Path(path_compressed).glob("*.nii.gz"))

counts_512 = []

for vessel_f, compressed_f in tqdm.tqdm(zip(vessel_files, compressed_files), total=len(vessel_files)):
    vessel_img = sitk.ReadImage(str(vessel_f))
    vessel_arr = sitk.GetArrayFromImage(vessel_img)

    compressed_img = sitk.ReadImage(str(compressed_f))
    compressed_arr = sitk.GetArrayFromImage(compressed_img)

    # check how many vessel voxels are == -512 in the compressed
    vessel_voxels = (vessel_arr > 0)  # assuming vessel voxels are > 0
    count_512 = ((compressed_arr == -512) & vessel_voxels).sum()
    counts_512.append(count_512)
    if count_512 > 0:
        print(f"{vessel_f.name}: {count_512} vessel voxels are -512 in compressed")
# Out:
#   0%|          | 4/1186 [00:06<36:13,  1.84s/it]
# Tr0004.nii.gz: 1249 vessel voxels are -512 in compressed
#   5%|▌         | 65/1186 [02:00<23:23,  1.25s/it]
# Tr0065.nii.gz: 1566 vessel voxels are -512 in compressed
#  12%|█▏        | 148/1186 [04:06<33:13,  1.92s/it]
# Tr0148.nii.gz: 47 vessel voxels are -512 in compressed
#  26%|██▌       | 309/1186 [09:25<29:37,  2.03s/it]
# Tr0309.nii.gz: 288 vessel voxels are -512 in compressed
#  32%|███▏      | 381/1186 [11:52<25:09,  1.87s/it]
# Tr0381.nii.gz: 23 vessel voxels are -512 in compressed
#  32%|███▏      | 383/1186 [11:55<24:39,  1.84s/it]
# Tr0383.nii.gz: 6 vessel voxels are -512 in compressed
#  37%|███▋      | 437/1186 [13:33<25:30,  2.04s/it]
# Tr0437.nii.gz: 187 vessel voxels are -512 in compressed
#  37%|███▋      | 443/1186 [13:43<20:34,  1.66s/it]
# Tr0443.nii.gz: 769 vessel voxels are -512 in compressed
#  42%|████▏     | 493/1186 [15:11<20:30,  1.78s/it]
# Tr0493.nii.gz: 3 vessel voxels are -512 in compressed
#  45%|████▌     | 537/1186 [16:13<14:05,  1.30s/it]
# Tr0537.nii.gz: 3 vessel voxels are -512 in compressed
#  45%|████▌     | 539/1186 [16:16<13:10,  1.22s/it]
# Tr0539.nii.gz: 112 vessel voxels are -512 in compressed
#  46%|████▌     | 545/1186 [16:23<13:17,  1.24s/it]
# Tr0545.nii.gz: 6 vessel voxels are -512 in compressed
#  48%|████▊     | 565/1186 [16:53<15:44,  1.52s/it]
# Tr0565.nii.gz: 10971 vessel voxels are -512 in compressed
#  49%|████▉     | 580/1186 [17:20<18:09,  1.80s/it]
# Tr0580.nii.gz: 3234 vessel voxels are -512 in compressed
#  53%|█████▎    | 631/1186 [18:47<15:56,  1.72s/it]
# Tr0631.nii.gz: 7 vessel voxels are -512 in compressed
#  55%|█████▍    | 650/1186 [19:17<17:42,  1.98s/it]
# Tr0650.nii.gz: 428 vessel voxels are -512 in compressed
#  58%|█████▊    | 688/1186 [20:20<11:18,  1.36s/it]
# Tr0688.nii.gz: 4477 vessel voxels are -512 in compressed
#  61%|██████    | 722/1186 [21:16<10:28,  1.36s/it]
# Tr0722.nii.gz: 17 vessel voxels are -512 in compressed
#  63%|██████▎   | 752/1186 [21:57<09:50,  1.36s/it]
# Tr0752.nii.gz: 5 vessel voxels are -512 in compressed
#  64%|██████▎   | 756/1186 [22:02<09:25,  1.31s/it]
# Tr0756.nii.gz: 12 vessel voxels are -512 in compressed
#  66%|██████▌   | 777/1186 [22:31<08:58,  1.32s/it]
# Tr0777.nii.gz: 3 vessel voxels are -512 in compressed
#  69%|██████▉   | 817/1186 [23:27<11:00,  1.79s/it]
# Tr0817.nii.gz: 41 vessel voxels are -512 in compressed
#  69%|██████▉   | 820/1186 [23:32<09:31,  1.56s/it]
# Tr0820.nii.gz: 20 vessel voxels are -512 in compressed
#  69%|██████▉   | 823/1186 [23:37<09:52,  1.63s/it]
# Tr0823.nii.gz: 8 vessel voxels are -512 in compressed
#  70%|███████   | 834/1186 [23:54<10:40,  1.82s/it]
# Tr0834.nii.gz: 37 vessel voxels are -512 in compressed
#  71%|███████   | 844/1186 [24:11<08:30,  1.49s/it]
# Tr0844.nii.gz: 41 vessel voxels are -512 in compressed
#  72%|███████▏  | 856/1186 [24:31<10:21,  1.88s/it]
# Tr0856.nii.gz: 2669 vessel voxels are -512 in compressed
#  78%|███████▊  | 928/1186 [26:22<06:35,  1.53s/it]
# Tr0928.nii.gz: 1 vessel voxels are -512 in compressed
#  81%|████████▏ | 964/1186 [27:23<05:55,  1.60s/it]

# %%
path_vessel = "/projects/vig/Datasets/aneurysm/cta_datasets/internal_train/crop_0.4_vessel"

path_uncompressed = "/projects/vig/Datasets/aneurysm/cta_datasets/internal_train/crop_0.4"

# for each scan, load both the vessel and uncompressed, then check how many vessel voxels (1 or 2) are <= -512
vessel_files = sorted(Path(path_vessel).glob("*.nii.gz"))
uncompressed_files = sorted(Path(path_uncompressed).glob("*.nii.gz"))
counts_512_uncompressed = []
for vessel_f, uncompressed_f in tqdm.tqdm(zip(vessel_files, uncompressed_files), total=len(vessel_files)):
    vessel_img = sitk.ReadImage(str(vessel_f))
    vessel_arr = sitk.GetArrayFromImage(vessel_img)

    uncompressed_img = sitk.ReadImage(str(uncompressed_f))
    uncompressed_arr = sitk.GetArrayFromImage(uncompressed_img)

    # check how many vessel voxels are <= -512 in the uncompressed
    vessel_voxels = (vessel_arr > 0)  # assuming vessel voxels are > 0
    count_512_uncompressed = ((uncompressed_arr <= -512) & vessel_voxels).sum()
    counts_512_uncompressed.append(count_512_uncompressed)
    if count_512_uncompressed > 0:
        print(f"{vessel_f.name}: {count_512_uncompressed} vessel voxels are <= -512 in uncompressed")
