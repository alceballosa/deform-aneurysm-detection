# %%
import pandas as pd

# %%
path_og = "./internal_train_crop_0.4.csv"
path_fps = "./fps_fixed.csv"

df = pd.read_csv(path_og)

# %%
df
# Out:
#           seriesuid  coordX  coordY  coordZ   w   h   d    lesion  volume  \
# 0     Tr0001.nii.gz   253.0   231.0   141.0  19  21  13  aneurysm  1499.0
# 1     Tr0002.nii.gz   236.0   196.5   213.5  15  12  14  aneurysm   975.0
# 2     Tr0003.nii.gz   315.5   326.5    75.5  20  16  16  aneurysm  1659.0
# 3     Tr0004.nii.gz   298.0   237.0   166.5   7   7   6  aneurysm   168.0
# 4     Tr0005.nii.gz   249.0   214.5   165.5   9   8  12  aneurysm   401.0
# ...             ...     ...     ...     ...  ..  ..  ..       ...     ...
# 1368  Tr1183.nii.gz   281.0   276.5   193.0  13  16  13  aneurysm  1253.0
# 1369  Tr1184.nii.gz   269.5   301.0   189.5   8   7   4  aneurysm   165.0
# 1370  Tr1185.nii.gz   280.0   264.5   214.0  21  22  23  aneurysm  3251.0
# 1371  Tr1186.nii.gz   328.0   261.5   196.0  15  12  11  aneurysm   858.0
# 1372  Tr1186.nii.gz   304.0   252.5   232.5  13  14  12  aneurysm  1253.0
#
#        min_axis   maj_axis  iom_artery  iom_vein
# 0     12.411585  21.317637    0.907939  0.010674
# 1     10.408462  17.395071    0.998974  0.000000
# 2     12.907482  19.155333    0.990958  0.000000
# 3      6.285128   8.259330    1.000000  0.000000
# 4      7.154678  13.706594    0.962594  0.000000
# ...         ...        ...         ...       ...
# 1368  10.679110  18.547994    0.723065  0.002394
# 1369   4.458395   9.245159    0.236364  0.763636
# 1370  12.740924  30.090392    0.866195  0.082436
# 1371   9.711334  17.275426    0.933566  0.041958
# 1372  11.738628  15.302447    0.955307  0.000000
#
# [1373 rows x 13 columns]

# %%
df_fps_og = pd.read_csv(path_fps).iloc[:, 2:20]
df_fps_og
# Out:
# /tmp/ipykernel_1100924/4286331924.py:1: DtypeWarning: Columns (11,12,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fps_og = pd.read_csv(path_fps).iloc[:, 2:20]
#           seriesuid  probability     coordX     coordY      coordZ          d  \
# 0     Tr0001.nii.gz     0.992386  264.82675  304.70288   55.607536  15.581342
# 1     Tr0001.nii.gz     0.945425  207.39828  205.01656  160.953900   5.864290
# 2     Tr0002.nii.gz     0.972559  236.02684  288.35358  130.364720  12.565471
# 3     Tr0002.nii.gz     0.963586  347.29272  223.22868    8.606861  37.163760
# 4     Tr0002.nii.gz     0.948249  367.75235  225.88980   51.977787   9.012156
# ...             ...          ...        ...        ...         ...        ...
# 1404  Tr1185.nii.gz     0.852029  201.01909  250.76064  258.549350   7.378265
# 1405  Tr1185.nii.gz     0.830833  188.24872  259.54950   64.345290   6.537921
# 1406  Tr1186.nii.gz     0.965628  248.64972  283.99197   67.101830  10.471547
# 1407  Tr1186.nii.gz     0.964017  358.46545  282.26907   27.951757   7.773346
# 1408  Tr1186.nii.gz     0.804690  378.57095  291.02545   83.100650  25.714330
#
#               h          w  is_fp  \
# 0     12.330435  12.551337      1
# 1      8.284704   8.960328      1
# 2     14.651035  14.723995      1
# 3     30.523613  29.429272      1
# 4     11.282431  11.766287      1
# ...         ...        ...    ...
# 1404   9.299912   9.971880      1
# 1405   8.895191   9.611685      1
# 1406  15.423156  15.434340      1
# 1407   9.695757  10.266037      1
# 1408  27.823280  27.181211      1
#
#                                                Comments Aneurysm  \
# 0                                  calcification of RV4  RICA-C7
# 1                                     branch of RMCA-M1      NaN
# 2     branch of right Posterior Inferior Cerebellar ...  RICA-C7
# 3                               not found (Left ICA-C2)      NaN
# 4                                   vessel of left face      NaN
# ...                                                 ...      ...
# 1404                                                NaN      NaN
# 1405                                                NaN      NaN
# 1406                                                NaN      NaN
# 1407                                                NaN      NaN
# 1408                                                NaN      NaN
#
#      Jisoo review (y-if agreed w anatomy) comments GY Comments is_FP  \
# 0                                       y      NaN         NaN     1
# 1                                       y      NaN         NaN     1
# 2                      vein in post fossa      NaN         NaN     1
# 3                                       y      NaN         NaN     1
# 4                                       y      NaN         NaN     1
# ...                                   ...      ...         ...   ...
# 1404                                  NaN      NaN         NaN   NaN
# 1405                                  NaN      NaN         NaN   NaN
# 1406                                  NaN      NaN         NaN   NaN
# 1407                                  NaN      NaN         NaN   NaN
# 1408                                  NaN      NaN         NaN   NaN
#
#       is_aneurysm  is_infundibulum  Unnamed: 19
# 0             NaN              NaN          NaN
# 1             NaN              NaN          NaN
# 2             NaN              NaN          NaN
# 3             NaN              NaN          NaN
# 4             NaN              NaN          NaN
# ...           ...              ...          ...
# 1404          NaN              NaN          NaN
# 1405          NaN              NaN          NaN
# 1406          NaN              NaN          NaN
# 1407          NaN              NaN          NaN
# 1408          NaN              NaN          NaN
#
# [1409 rows x 18 columns]

# %% [markdown]
# ## Remove only annotated aneurysms

# %%
# Out:
# array([True, False, None], dtype=object)

# %%
def remove_aneurysms_but_keep_non_reviewed(row):
    # if jisoo marked as aneurysm then remove
    if row["is_aneurysm"] == 1:
        return False
    # if jisoo marked as non-aneurysm then keep
    elif row["is_FP"] == "1" or row["is_FP"] == "1P":
        return True
    # if jisoo marked as infundibulum then discard
    elif row["is_infundibulum"] == 1:
        return True
    # if either of these are NaN, we need to check the Aneurysm column
    else:
        return True 


df_fps = df_fps_og.copy()
df_fps["keep"] = df_fps.apply(remove_aneurysms_but_keep_non_reviewed, axis=1)
df_fps_non_r = df_fps[df_fps["keep"]]
df_fps_non_r["lesion"] = "non_aneurysm"
df_fps_non_r
# Out:
# /tmp/ipykernel_581708/660795979.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r["lesion"] = "non_aneurysm"
#           seriesuid  probability     coordX     coordY      coordZ          d  \
# 0     Tr0001.nii.gz     0.992386  264.82675  304.70288   55.607536  15.581342
# 1     Tr0001.nii.gz     0.945425  207.39828  205.01656  160.953900   5.864290
# 2     Tr0002.nii.gz     0.972559  236.02684  288.35358  130.364720  12.565471
# 3     Tr0002.nii.gz     0.963586  347.29272  223.22868    8.606861  37.163760
# 4     Tr0002.nii.gz     0.948249  367.75235  225.88980   51.977787   9.012156
# ...             ...          ...        ...        ...         ...        ...
# 1404  Tr1185.nii.gz     0.852029  201.01909  250.76064  258.549350   7.378265
# 1405  Tr1185.nii.gz     0.830833  188.24872  259.54950   64.345290   6.537921
# 1406  Tr1186.nii.gz     0.965628  248.64972  283.99197   67.101830  10.471547
# 1407  Tr1186.nii.gz     0.964017  358.46545  282.26907   27.951757   7.773346
# 1408  Tr1186.nii.gz     0.804690  378.57095  291.02545   83.100650  25.714330
#
#               h          w  is_fp  \
# 0     12.330435  12.551337      1
# 1      8.284704   8.960328      1
# 2     14.651035  14.723995      1
# 3     30.523613  29.429272      1
# 4     11.282431  11.766287      1
# ...         ...        ...    ...
# 1404   9.299912   9.971880      1
# 1405   8.895191   9.611685      1
# 1406  15.423156  15.434340      1
# 1407   9.695757  10.266037      1
# 1408  27.823280  27.181211      1
#
#                                                Comments Aneurysm  \
# 0                                  calcification of RV4  RICA-C7
# 1                                     branch of RMCA-M1      NaN
# 2     branch of right Posterior Inferior Cerebellar ...  RICA-C7
# 3                               not found (Left ICA-C2)      NaN
# 4                                   vessel of left face      NaN
# ...                                                 ...      ...
# 1404                                                NaN      NaN
# 1405                                                NaN      NaN
# 1406                                                NaN      NaN
# 1407                                                NaN      NaN
# 1408                                                NaN      NaN
#
#      Jisoo review (y-if agreed w anatomy) comments GY Comments is_FP  \
# 0                                       y      NaN         NaN     1
# 1                                       y      NaN         NaN     1
# 2                      vein in post fossa      NaN         NaN     1
# 3                                       y      NaN         NaN     1
# 4                                       y      NaN         NaN     1
# ...                                   ...      ...         ...   ...
# 1404                                  NaN      NaN         NaN   NaN
# 1405                                  NaN      NaN         NaN   NaN
# 1406                                  NaN      NaN         NaN   NaN
# 1407                                  NaN      NaN         NaN   NaN
# 1408                                  NaN      NaN         NaN   NaN
#
#       is_aneurysm  is_infundibulum  Unnamed: 19  keep        lesion
# 0             NaN              NaN          NaN  True  non_aneurysm
# 1             NaN              NaN          NaN  True  non_aneurysm
# 2             NaN              NaN          NaN  True  non_aneurysm
# 3             NaN              NaN          NaN  True  non_aneurysm
# 4             NaN              NaN          NaN  True  non_aneurysm
# ...           ...              ...          ...   ...           ...
# 1404          NaN              NaN          NaN  True  non_aneurysm
# 1405          NaN              NaN          NaN  True  non_aneurysm
# 1406          NaN              NaN          NaN  True  non_aneurysm
# 1407          NaN              NaN          NaN  True  non_aneurysm
# 1408          NaN              NaN          NaN  True  non_aneurysm
#
# [1377 rows x 20 columns]

# %%
cols_to_add = ["volume", "min_axis", "maj_axis", "iom_artery", "iom_vein"]
for col in cols_to_add:
    if col not in df_fps_non_r.columns:
        df_fps_non_r[col] = None
df_fps_non_r = df_fps_non_r[df.columns]
df_fps_non_r
# Out:
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
#           seriesuid     coordX     coordY      coordZ          w          h  \
# 0     Tr0001.nii.gz  264.82675  304.70288   55.607536  12.551337  12.330435
# 1     Tr0001.nii.gz  207.39828  205.01656  160.953900   8.960328   8.284704
# 2     Tr0002.nii.gz  236.02684  288.35358  130.364720  14.723995  14.651035
# 3     Tr0002.nii.gz  347.29272  223.22868    8.606861  29.429272  30.523613
# 4     Tr0002.nii.gz  367.75235  225.88980   51.977787  11.766287  11.282431
# ...             ...        ...        ...         ...        ...        ...
# 1404  Tr1185.nii.gz  201.01909  250.76064  258.549350   9.971880   9.299912
# 1405  Tr1185.nii.gz  188.24872  259.54950   64.345290   9.611685   8.895191
# 1406  Tr1186.nii.gz  248.64972  283.99197   67.101830  15.434340  15.423156
# 1407  Tr1186.nii.gz  358.46545  282.26907   27.951757  10.266037   9.695757
# 1408  Tr1186.nii.gz  378.57095  291.02545   83.100650  27.181211  27.823280
#
#               d        lesion volume min_axis maj_axis iom_artery iom_vein
# 0     15.581342  non_aneurysm   None     None     None       None     None
# 1      5.864290  non_aneurysm   None     None     None       None     None
# 2     12.565471  non_aneurysm   None     None     None       None     None
# 3     37.163760  non_aneurysm   None     None     None       None     None
# 4      9.012156  non_aneurysm   None     None     None       None     None
# ...         ...           ...    ...      ...      ...        ...      ...
# 1404   7.378265  non_aneurysm   None     None     None       None     None
# 1405   6.537921  non_aneurysm   None     None     None       None     None
# 1406  10.471547  non_aneurysm   None     None     None       None     None
# 1407   7.773346  non_aneurysm   None     None     None       None     None
# 1408  25.714330  non_aneurysm   None     None     None       None     None
#
# [1377 rows x 13 columns]

# %%
# combine with original df

df_combined_non_r = pd.concat([df, df_fps_non_r], ignore_index=True)
df_combined_non_r.to_csv("./internal_train_crop_0.4_mixed_fps_fix.csv", index=False)
# Out:
# /tmp/ipykernel_581708/7634857.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_combined_non_r = pd.concat([df, df_fps_non_r], ignore_index=True)

# %%
def remove_aneurysms_and_not_reviewed(row):
    # if jisoo marked as aneurysm then remove
    if row["is_aneurysm"] == 1:
        return False
    # if jisoo marked as non-aneurysm then keep
    elif row["is_FP"] == "1" or row["is_FP"] == "1P":
        return True
    # if jisoo marked as infundibulum then discard
    elif row["is_infundibulum"] == 1:
        return True
    # if either of these are NaN, we need to check the Aneurysm column
    if pd.isna(row["is_aneurysm"]) and pd.isna(row["is_FP"]) and pd.isna(row["is_infundibulum"]):
        return False 

df_fps = df_fps_og.copy()
df_fps["keep"] = df_fps.apply(remove_aneurysms_and_not_reviewed, axis=1)
df_fps_non_r = df_fps[df_fps["keep"]]
df_fps_non_r["lesion"] = "non_aneurysm"
df_fps_non_r
# Out:
# /tmp/ipykernel_581708/1856952655.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r["lesion"] = "non_aneurysm"
#          seriesuid  probability     coordX     coordY      coordZ          d  \
# 0    Tr0001.nii.gz     0.992386  264.82675  304.70288   55.607536  15.581342
# 1    Tr0001.nii.gz     0.945425  207.39828  205.01656  160.953900   5.864290
# 2    Tr0002.nii.gz     0.972559  236.02684  288.35358  130.364720  12.565471
# 3    Tr0002.nii.gz     0.963586  347.29272  223.22868    8.606861  37.163760
# 4    Tr0002.nii.gz     0.948249  367.75235  225.88980   51.977787   9.012156
# ..             ...          ...        ...        ...         ...        ...
# 236  Tr0180.nii.gz     0.929836  301.69382  244.71230   67.289140  17.432417
# 237  Tr0180.nii.gz     0.858953  164.27654  241.96536   74.848010   8.093696
# 238  Tr0180.nii.gz     0.817705  209.41397  156.24464  216.102260   7.951198
# 239  Tr0180.nii.gz     0.810347  170.55316  257.11450   27.575535  36.721780
# 240  Tr0181.nii.gz     0.960579  259.29913  217.83655  175.258480   7.810250
#
#              h          w  is_fp  \
# 0    12.330435  12.551337      1
# 1     8.284704   8.960328      1
# 2    14.651035  14.723995      1
# 3    30.523613  29.429272      1
# 4    11.282431  11.766287      1
# ..         ...        ...    ...
# 236  16.915300  17.161490      1
# 237  11.487050  12.044621      1
# 238  10.484603  11.056930      1
# 239  33.171350  31.917814      1
# 240  12.033678  12.369130      1
#
#                                               Comments Aneurysm  \
# 0                                 calcification of RV4  RICA-C7
# 1                                    branch of RMCA-M1      NaN
# 2    branch of right Posterior Inferior Cerebellar ...  RICA-C7
# 3                              not found (Left ICA-C2)      NaN
# 4                                  vessel of left face      NaN
# ..                                                 ...      ...
# 236                                               LECA      NaN
# 237                                   Maxillary artery      NaN
# 238                                  Ophthalmic artery      NaN
# 239                                               RCCA      NaN
# 240                                     Basilar Artery  LICA-C7
#
#     Jisoo review (y-if agreed w anatomy) comments GY Comments is_FP  \
# 0                                      y      NaN         NaN     1
# 1                                      y      NaN         NaN     1
# 2                     vein in post fossa      NaN         NaN     1
# 3                                      y      NaN         NaN     1
# 4                                      y      NaN         NaN     1
# ..                                   ...      ...         ...   ...
# 236                                  NaN      NaN         NaN    1P
# 237                                  NaN      NaN         NaN    1P
# 238                                  NaN      NaN         NaN    1P
# 239                                  NaN      NaN         NaN    1P
# 240                                  NaN      NaN         NaN    1P
#
#      is_aneurysm  is_infundibulum  Unnamed: 19  keep        lesion
# 0            NaN              NaN          NaN  True  non_aneurysm
# 1            NaN              NaN          NaN  True  non_aneurysm
# 2            NaN              NaN          NaN  True  non_aneurysm
# 3            NaN              NaN          NaN  True  non_aneurysm
# 4            NaN              NaN          NaN  True  non_aneurysm
# ..           ...              ...          ...   ...           ...
# 236          NaN              NaN          NaN  True  non_aneurysm
# 237          NaN              NaN          NaN  True  non_aneurysm
# 238          NaN              NaN          NaN  True  non_aneurysm
# 239          NaN              NaN          NaN  True  non_aneurysm
# 240          NaN              NaN          NaN  True  non_aneurysm
#
# [209 rows x 20 columns]

# %%
cols_to_add = ["volume", "min_axis", "maj_axis", "iom_artery", "iom_vein"]
for col in cols_to_add:
    if col not in df_fps_non_r.columns:
        df_fps_non_r[col] = None
df_fps_non_r = df_fps_non_r[df.columns]
df_fps_non_r
# Out:
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
# /tmp/ipykernel_581708/4186681180.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_fps_non_r[col] = None
#          seriesuid     coordX     coordY      coordZ          w          h  \
# 0    Tr0001.nii.gz  264.82675  304.70288   55.607536  12.551337  12.330435
# 1    Tr0001.nii.gz  207.39828  205.01656  160.953900   8.960328   8.284704
# 2    Tr0002.nii.gz  236.02684  288.35358  130.364720  14.723995  14.651035
# 3    Tr0002.nii.gz  347.29272  223.22868    8.606861  29.429272  30.523613
# 4    Tr0002.nii.gz  367.75235  225.88980   51.977787  11.766287  11.282431
# ..             ...        ...        ...         ...        ...        ...
# 236  Tr0180.nii.gz  301.69382  244.71230   67.289140  17.161490  16.915300
# 237  Tr0180.nii.gz  164.27654  241.96536   74.848010  12.044621  11.487050
# 238  Tr0180.nii.gz  209.41397  156.24464  216.102260  11.056930  10.484603
# 239  Tr0180.nii.gz  170.55316  257.11450   27.575535  31.917814  33.171350
# 240  Tr0181.nii.gz  259.29913  217.83655  175.258480  12.369130  12.033678
#
#              d        lesion volume min_axis maj_axis iom_artery iom_vein
# 0    15.581342  non_aneurysm   None     None     None       None     None
# 1     5.864290  non_aneurysm   None     None     None       None     None
# 2    12.565471  non_aneurysm   None     None     None       None     None
# 3    37.163760  non_aneurysm   None     None     None       None     None
# 4     9.012156  non_aneurysm   None     None     None       None     None
# ..         ...           ...    ...      ...      ...        ...      ...
# 236  17.432417  non_aneurysm   None     None     None       None     None
# 237   8.093696  non_aneurysm   None     None     None       None     None
# 238   7.951198  non_aneurysm   None     None     None       None     None
# 239  36.721780  non_aneurysm   None     None     None       None     None
# 240   7.810250  non_aneurysm   None     None     None       None     None
#
# [209 rows x 13 columns]

# %%
df_combined_non_r = pd.concat([df, df_fps_non_r], ignore_index=True)
df_combined_non_r.to_csv("./internal_train_crop_0.4_confirmed_fps_fix.csv", index=False)

# %%
path_og = "./internal_train_crop_0.4.csv"
path_fps = "./fps_fixed.csv"

df = pd.read_csv(path_og)

df_fps = df_fps_og.copy()

# %%
def keep_aneurysms_and_keep_non_reviewed(row):
    # if jisoo marked as aneurysm then remove
    if row["is_aneurysm"] == 1:
        return "aneurysm"
    # if jisoo marked as non-aneurysm then keep
    elif row["is_FP"] == "1" or row["is_FP"] == "1P":
        return "non_aneurysm"
    # if jisoo marked as infundibulum then discard
    elif row["is_infundibulum"] == 1:
        return "non_aneurysm"
    # if either of these are NaN, we need to check the Aneurysm column
    else:
        return "non_aneurysm"


df_fps = df_fps_og.copy()
df_fps["lesion"] = df_fps.apply(keep_aneurysms_and_keep_non_reviewed, axis=1)
df_fps_non_r = df_fps.copy()
cols_to_add = ["volume", "min_axis", "maj_axis", "iom_artery", "iom_vein"]
for col in cols_to_add:
    if col not in df_fps_non_r.columns:
        df_fps_non_r[col] = None

df_fps_non_r = df_fps_non_r[df.columns]
df_fps_non_r["lesion"].value_counts()
# Out:
# lesion
# non_aneurysm    1377
# aneurysm          32
# Name: count, dtype: int64

# %%
df_fps["is_aneurysm"].value_counts()
# Out:
# is_aneurysm
# 1.0    32
# Name: count, dtype: int64

# %%
df_combined_non_r = pd.concat([df, df_fps_non_r], ignore_index=True)
df_combined_non_r.to_csv("./internal_train_crop_0.4_fps_fix_extra_aneu.csv", index=False)
# Out:
# /tmp/ipykernel_1100924/1255633651.py:1: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_combined_non_r = pd.concat([df, df_fps_non_r], ignore_index=True)

# %%
import pandas as pd
import numpy as np

# %%
path_og = "./internal_train_crop_0.4.csv"
path_fps = "./fps_fixed.csv"

df = pd.read_csv(path_og)
df_fps_og = pd.read_csv(path_fps).iloc[:, 2:20]
df_fps = df_fps_og.copy()
# Out:
# /tmp/ipykernel_206826/3855631394.py:5: DtypeWarning: Columns (11,12,13,14,15,16) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_fps_og = pd.read_csv(path_fps).iloc[:, 2:20]

# %%
def keep_aneurysms_and_keep_only_reviewed(row):
    # if jisoo marked as aneurysm then remove
    if row["is_aneurysm"] == 1:
        return "aneurysm"
    # if jisoo marked as non-aneurysm then keep
    elif row["is_FP"] == "1" or row["is_FP"] == "1P":
        return "non_aneurysm"
    # if jisoo marked as infundibulum then discard
    elif row["is_infundibulum"] == 1:
        return "non_aneurysm"
    # if either of these are NaN, we need to check the Aneurysm column
    else:
        return "remove"


df_fps = df_fps_og.copy()
df_fps["lesion"] = df_fps.apply(keep_aneurysms_and_keep_only_reviewed, axis=1)
df_fps_non_r = df_fps.copy()
cols_to_add = ["volume", "min_axis", "maj_axis", "iom_artery", "iom_vein"]
for col in cols_to_add:
    if col not in df_fps_non_r.columns:
        df_fps_non_r[col] = None

df_fps_non_r = df_fps_non_r[df.columns]
df_fps_non_r["lesion"].value_counts()
# Out:
# lesion
# remove          1168
# non_aneurysm     209
# aneurysm          32
# Name: count, dtype: int64

# %%
df_fps_non_r = df_fps_non_r[df_fps_non_r["lesion"] != "remove"]
df_fps["is_aneurysm"].value_counts()
df_combined_non_r = pd.concat([df, df_fps_non_r], ignore_index=True)
df_combined_non_r.to_csv(
    "./internal_train_crop_0.4_confirmed_fps_fix_extra_aneu.csv", index=False
)
# -*- coding: utf-8 -*-
# Out:
# /tmp/ipykernel_206826/1828904451.py:3: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df_combined_non_r = pd.concat([df, df_fps_non_r], ignore_index=True)
